# %% [markdown]
# <div align="center">
#   <img src="../img/wsu_logo_horizontal.png" alt="Wayne State University Logo" width="320">
#   <h1>Homework 1: Python Basics and<br>Basic Visualization</h1>
# </div>
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/WSU-AI-in-ME/ai-in-me-1/blob/main/homework/hw01_python_basics_and_visualization.ipynb)
#
# [Course Repository](https://github.com/WSU-AI-in-ME/ai-in-me-1) · [Homework Index](https://github.com/WSU-AI-in-ME/ai-in-me-1/blob/main/Homework_index.ipynb)
#
# **ME 5995 — AI in Mechanical Engineering I: Fundamentals of Manufacturing Data Science**
# **Wayne State University**
#
# **Course:** ME 5995 – AI in Mechanical Engineering I
# **Version:** Student Starter
# **Estimated completion time:** 60–90 minutes
# **Total points:** 100

# %% [markdown]
# ## Student Information
#
# Double-click this Markdown cell in Colab and enter your information.
#
# **Student name:** TODO: Enter your name
# **WSU AccessID:** TODO: Enter your WSU AccessID

# %% [markdown]
# ## Learning objectives
#
# After completing this homework, you should be able to:
#
# - define Python variables and inspect basic data types;
# - perform a unit conversion using appropriate numerical types;
# - use positive indexing, negative indexing, and slicing with Python lists;
# - organize manufacturing-process metadata in a dictionary;
# - write a conditional statement, loop, and simple function;
# - use concise comments to document purpose, units, assumptions, and reasoning;
# - create a correctly labeled engineering plot with Matplotlib; and
# - distinguish a trend directly visible in a graph from an unsupported causal
#   explanation.
#
# ## Scope and context
#
# All numerical values in this notebook are small, course-created examples for
# Python practice. No manufacturing background is required. Do not use NumPy,
# pandas, CSV files, or other data-processing libraries.
#
# ## Code comment expectations
#
# Use comments throughout the code you write.
#
# - Use a **full-line comment** above a calculation or code section to explain
#   its purpose, reasoning, assumption, or unit.
# - Use a short **inline comment** only when a brief clarification is helpful.
# - Use consecutive `#` lines for a longer note; Python has no separate
#   block-comment syntax.
# - Use the provided `# TODO:` comments to locate required work. Replace or
#   supplement them with comments that explain your completed approach.
# - A triple-quoted string inside a function is a **docstring**, not an ordinary
#   comment. It briefly documents what the function returns.
#
# Do not comment every obvious statement. Comments should add information that
# is not already clear from the code and variable names.
#
# ## Submission instructions
#
# Submit both (1) the completed Jupyter notebook (`.ipynb`) with all code cells
# executed and outputs visible and (2) a PDF version of the completed notebook
# through Canvas.
#
# Use these filenames:
#
# - `HW01_Firstname_Lastname.ipynb`
# - `HW01_Firstname_Lastname.pdf`
#
# Before exporting, select **Runtime → Restart session and run all**, or use the
# equivalent command in your notebook environment. Confirm that the notebook
# runs from top to bottom without errors.

# %% [markdown]
# # Part 1 — Variables, Data Types, and Unit Conversion — 15 points
#
# Define variables describing one hypothetical machining test.
#
# 1. Define `material` as text.
# 2. Define `spindle_speed_rpm` as an integer.
# 3. Define `feed_rate_mm_min` as a float.
# 4. Define `sampling_rate_hz` as an integer.
# 5. Define `recording_duration_s` as a float.
# 6. Define `coolant_used` as a Boolean value.
# 7. Print every variable's value and the result of `type()`.
# 8. Convert feed rate from millimeters per minute to millimeters per second:
#
#    `feed_rate_mm_s = feed_rate_mm_min / 60`
#
# 9. Print the converted feed rate with the unit `mm/s`.

# %%
# Part 1 starter code
seconds_per_minute = 60

# TODO: Define the six requested variables using appropriate data types.

# TODO: Print each variable's value and type.

# TODO: Convert feed rate from mm/min to mm/s.

# TODO: Print the converted feed rate with its unit.

# %% [markdown]
# # Part 2 — Lists, Indexing, and Slicing — 20 points
#
# The provided list contains tool-wear measurements from seven hypothetical
# machining tests. Each value is measured in micrometers (`µm`).
#
# 1. Select and print the first measurement using positive indexing.
# 2. Select and print the last measurement using negative indexing.
# 3. Slice and print the second through fourth measurements.
# 4. Slice and print the first three measurements.
# 5. Slice and print the last three measurements.
# 6. Print the number of measurements using `len()`.
#
# Remember that a slice includes its start index and excludes its stop index.

# %%
# Part 2 starter code
wear_measurements_um = [12, 17, 25, 34, 46, 59, 73]

# TODO: Select and print the first measurement.

# TODO: Select and print the last measurement using negative indexing.

# TODO: Slice and print the second through fourth measurements.

# TODO: Slice and print the first three measurements.

# TODO: Slice and print the last three measurements.

# TODO: Print the number of measurements.

# %% [markdown]
# # Part 3 — Manufacturing Metadata Dictionary — 15 points
#
# A dictionary stores labeled metadata as key–value pairs.
#
# 1. Create a dictionary named `process_metadata` with these keys:
#    - `material`
#    - `tool_id`
#    - `spindle_speed_rpm`
#    - `feed_rate_mm_min`
#    - `sampling_rate_hz`
#    - `sensor_channels`
# 2. Use the provided `sensor_channels` list as the value associated with the
#    `sensor_channels` key.
# 3. Print the `tool_id` and `sampling_rate_hz` values by accessing their keys.
# 4. Add one new metadata field named `operator_shift` and assign a short text
#    value.
# 5. Print the completed dictionary.

# %%
# Part 3 starter code
sensor_channels = ["Force X", "Vibration X", "Temperature"]

# TODO: Create process_metadata with all six required keys.

# TODO: Print tool_id and sampling_rate_hz by accessing their keys.

# TODO: Add operator_shift and print the completed dictionary.

# %% [markdown]
# # Part 4 — Conditional Statement, Loop, and Function — 20 points
#
# Use `wear_measurements_um` from Part 2 and the provided threshold.
#
# 1. Write a `for` loop that prints each test number and tool-wear value.
# 2. Inside the loop, use an `if/else` statement to print `High wear` when the
#    value is greater than or equal to `wear_threshold_um`; otherwise print
#    `Normal`.
# 3. Define `classify_wear(wear_value_um, threshold_um)` so that it returns
#    `"High wear"` or `"Normal"` using the same rule.
# 4. Test the function with at least two wear values, including one value below
#    and one value at or above the threshold.
#
# **Important:** This threshold classification is only a programming exercise.
# It is not a validated tool-replacement criterion and must not be interpreted as
# one.

# %%
# Part 4 starter code
wear_threshold_um = 50

# TODO: Write a loop that prints each test number, wear value, and category.


def classify_wear(wear_value_um, threshold_um):
    '''Return a course-example wear category for one value.'''
    # TODO: Return "Normal" or "High wear" using an if statement.
    pass


# TODO: Call classify_wear() with at least two values and print the results.

# %% [markdown]
# # Part 5 — Basic Manufacturing Data Visualization — 30 points
#
# The provided lists contain course-created tool-wear values for six consecutive
# cuts. Create one line plot using Matplotlib.
#
# 1. Create a figure with an appropriate size.
# 2. Plot `tool_wear_plot_um` versus `cut_number` using both a line and marker.
# 3. Label the x-axis `Cut number`.
# 4. Label the y-axis `Tool wear (µm)`.
# 5. Add a descriptive title.
# 6. Add a grid and legend.
# 7. Call `fig.tight_layout()` and `plt.show()`.
# 8. Answer both interpretation questions in the Markdown cell below the plot.
#
# The written response should contain 2–3 complete sentences and distinguish a
# direct observation from a possible physical cause.

# %%
# Part 5 starter code
import matplotlib.pyplot as plt

cut_number = [1, 2, 3, 4, 5, 6]
tool_wear_plot_um = [18, 24, 31, 39, 50, 63]

# TODO: Create a figure with an appropriate size.

# TODO: Plot tool wear versus cut number with a line, marker, and legend label.

# TODO: Add the required axis labels, title, grid, and legend.

# TODO: Apply tight_layout() and display the plot.

# %% [markdown]
# ## Part 5 Written Response
#
# 1. **What trend can be directly observed from the plot?**
#    TODO: Write your response here.
#
# 2. **Can this plot alone establish the physical cause of the observed trend?
#    Explain briefly.**
#    TODO: Write your response here.
#
# Write a total of 2–3 complete sentences.

# %% [markdown]
# # Final Submission Checklist
#
# Rendered notebook checkboxes are not clickable. To record completion, edit
# this Markdown cell and change `[ ]` to `[x]`.
#
# - [ ] I entered my name and WSU AccessID.
# - [ ] Part 1 is complete and all units are shown.
# - [ ] Part 2 uses positive indexing, negative indexing, and slicing.
# - [ ] Part 3 contains all required dictionary keys.
# - [ ] Part 4 includes a loop, condition, function, and two function tests.
# - [ ] Part 5 includes all required plot elements and a 2–3 sentence response.
# - [ ] My completed code includes useful comments about purpose, units,
#       assumptions, or reasoning.
# - [ ] I selected **Restart session and run all** and resolved all errors.
# - [ ] All code-cell outputs are visible.
# - [ ] I saved the notebook as `HW01_Firstname_Lastname.ipynb`.
# - [ ] I saved the PDF as `HW01_Firstname_Lastname.pdf`.
# - [ ] I will submit both files through Canvas.
