# %% [markdown]
# <table style="border:none; width:100%; padding:0;">
#   <tr style="border:none;">
#     <td style="border:none; text-align:left; vertical-align:middle; width:40%;">
#       <img src="img/wsu_logo_horizontal.png" alt="Wayne State University Logo" width="300">
#     </td>
#     <td style="border:none; text-align:right; vertical-align:middle; width:60%;">
#       <h1 style="margin:0;">AI in Mechanical Engineering I: <br>Tutorial Index</h1>
#     </td>
#   </tr>
# </table>
#
# Welcome to the hands-on coding tutorials for **AI in Mechanical Engineering I: Fundamentals and Machine Learning**.
#
# Click on the badges below to open each week's interactive tutorial directly in Google Colab.
#
# ### Phase 1: Python Foundations and Engineering Data Handling
#
# *   **Week 1: Python Basics & Environment Setup**
#     *   Learn the core syntax, data types, sequences (lists, tuples), and control flows in Python.
#     *   [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/WSU-AI-in-ME/ai-in-me-1/blob/main/tutorials/Week1_Python_Basics.ipynb)
#
# *   **Week 2: Scientific Computing with Python**
#     *   Introduction to numerical computing and data visualization using NumPy, Pandas, and Matplotlib.
#     *   [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/WSU-AI-in-ME/ai-in-me-1/blob/main/tutorials/Week2_Scientific_Computing.ipynb)
#
# *(Future tutorials for Weeks 3-15 will be updated here.)*
