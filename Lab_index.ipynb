# %% [markdown]
# <table style="border:none; width:100%; padding:0;">
#   <tr style="border:none;">
#     <td style="border:none; text-align:left; vertical-align:middle; width:40%;">
#       <img src="img/wsu_logo_horizontal.png" alt="Wayne State University Logo" width="300">
#     </td>
#     <td style="border:none; text-align:right; vertical-align:middle; width:60%;">
#       <h1 style="margin:0;">AI in Mechanical Engineering I:<br>Lab Index</h1>
#     </td>
#   </tr>
# </table>
#
# **ME 5995 — Fundamentals of Manufacturing Data Science**
# Wayne State University · Fall 2026
#
# Labs combine guided instruction with required assessed checkpoints. Open the
# notebook from the badge below, save a personal copy in Google Drive, and submit
# the required files through Canvas. Canvas and the course syllabus are
# authoritative for deadlines, grading requirements, and course policies. Add
# concise comments to code you write so that purpose, assumptions, units, and
# non-obvious reasoning are clear.
#
# ## Week 1 — Course Introduction and Python Basics
#
# ### Lab 0 (Guided Example): Google Colab and Python Quick Start
#
# Optional, ungraded, and completed together during class. Practice Markdown
# editing, cell execution order, runtime state, restarting, and exporting a Colab
# notebook.
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/WSU-AI-in-ME/ai-in-me-1/blob/main/labs/week01/lab00_colab_and_python_quick_start.ipynb)
#
# ### Lab 1: Python Basics and Visualization for Manufacturing Data
#
# Practice Python variables, data types, lists, vector-like sequences,
# list-based tables, dictionaries, conditions, loops, functions, and basic
# Matplotlib visualization using short Python lists.
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/WSU-AI-in-ME/ai-in-me-1/blob/main/labs/week01/lab01_python_basics_and_visualization.ipynb)
#
# ## Week 2 — Scientific Computing with Manufacturing Data
#
# ### Lab 2: Scientific Computing with Manufacturing Data
#
# Use NumPy and pandas to inspect and visualize one curated PHM 2010 machining
# record with documented physical time and sensor units.
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/WSU-AI-in-ME/ai-in-me-1/blob/main/labs/week02/lab02_scientific_computing_with_manufacturing_data.ipynb)
#
# Additional labs will be added as course materials are released.
