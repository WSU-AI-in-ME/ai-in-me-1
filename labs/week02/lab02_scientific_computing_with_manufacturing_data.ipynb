# %% [markdown]
# <div align="center">
#   <img src="../../img/wsu_logo_horizontal.png" alt="Wayne State University Logo" width="320">
#   <h1>Lab 2: Scientific Computing with<br>Manufacturing Data</h1>
# </div>
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/WSU-AI-in-ME/ai-in-me-1/blob/main/labs/week02/lab02_scientific_computing_with_manufacturing_data.ipynb)
#
# [Course Repository](https://github.com/WSU-AI-in-ME/ai-in-me-1) · [Lab Index](https://github.com/WSU-AI-in-ME/ai-in-me-1/blob/main/Lab_index.ipynb)
#
# **ME 5995 — AI in Mechanical Engineering I: Fundamentals of Manufacturing Data Science**
# **Wayne State University · Fall 2026**
#
# **Graded lab · Individual work · Target time: approximately 60–75 minutes**
# **Version:** Student Notebook

# %% [markdown]
# ## Student Information
#
# Double-click this Markdown cell in Colab and enter your information.
#
# **Student name:** TODO: Enter your name
# **WSU AccessID:** TODO: Enter your WSU AccessID

# %% [markdown]
# ## Prerequisites
#
# Complete [Lab 0](../week01/lab00_colab_and_python_quick_start.ipynb) and
# [Lab 1](../week01/lab01_python_basics_and_visualization.ipynb) first. This lab
# assumes basic Python variables, lists, dictionaries, loops, functions, and
# Matplotlib plotting.
#
# ## Overview and objectives
#
# Use NumPy and pandas to inspect one complete PHM 2010 machining record,
# construct physical time, summarize and plot one channel, and separate an
# observation from a possible interpretation and limitation.
#
# ## Submission
#
# Submit `Lab02_Firstname_Lastname.ipynb` and
# `Lab02_Firstname_Lastname.pdf` through Canvas. A separate report is not
# required. Add concise comments to code you write so that processing steps,
# assumptions, and physical units are clear.

# %% [markdown]
# # Part 1 — NumPy Fundamentals
#
# ## [GUIDED] Commenting scientific code
#
# Continue the Week 1 commenting practice. Use full-line comments for the purpose
# of a processing step and short inline comments for a unit or brief assumption.
# For multi-step scientific code, comments should make the analysis sequence and
# engineering meaning clear. Avoid restating obvious assignments.
#
# ## [GUIDED] Lists and arrays
#
# Python-list repetition and NumPy multiplication have different meanings.

# %%
# Import each scientific-computing library with its conventional alias.
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Compare a Python language operation with a NumPy numerical operation.
python_list = [1, 2, 3]
numpy_array = np.array([1, 2, 3])
print("List repetition:", python_list * 2)
print("Array multiplication:", numpy_array * 2)
print("Array shape:", numpy_array.shape)

# %%
# [REQUIRED CHECKPOINT 1] NumPy Array Operations
example_signal = np.array([0.20, 0.35, -0.10, 0.15, 0.05])

# TODO: Select the first value and first three values.
first_value = ...
first_three = ...

# TODO: Multiply every array value by 2 and calculate the mean.
scaled_signal = ...
mean_value = ...

print(first_value)
print(first_three)
print(scaled_signal)
print(mean_value)

# %% [markdown]
# # Part 2 — Load and Inspect the PHM 2010 Record
#
# The original challenge studied remaining-life estimation for high-speed CNC
# milling cutters. This course file is the complete cutter `c1`, cut 158
# acquisition record from the Kaggle Version 1 mirror. It contains seven
# simultaneously sampled channels. Each row contains one sample from each channel
# at 50 kHz. One record alone cannot establish tool wear, chatter, anomaly, or
# failure.
#
# See the [PHM 2010 dataset README](../../data/phm2010/README.md) for
# license, provenance, transformations, and checksums.

# %%
# Load the curated CSV directly from the course repository.
data_url = "https://raw.githubusercontent.com/WSU-AI-in-ME/ai-in-me-1/main/data/phm2010/c1_selected_cuts/c1_cut158.csv"
data = pd.read_csv(data_url)
print("Loaded:", data_url)
print("Shape:", data.shape)

# %%
# Preview only a few rows to avoid an oversized notebook output.
display(data.head())
# Inspect labels and data types before selecting a signal.
print("Columns:", data.columns.tolist())
print("Data types:")
print(data.dtypes)

# %%
# [REQUIRED CHECKPOINT 2] DataFrame Inspection
# TODO: Report the number of rows and sensor channels.
number_of_rows = ...
number_of_channels = ...

# TODO: Convert the column names to a list.
data_columns = ...

# TODO: Count missing values in every column.
missing_values = ...

print("Rows:", number_of_rows)
print("Channels:", number_of_channels)
print("Columns:", data_columns)
print("Missing values:")
print(missing_values)

# %% [markdown]
# ### [REQUIRED CHECKPOINT 2] Physical Meaning
#
# TODO: Explain what one row represents and identify the seven channel quantities
# and physical units using the dataset README.

# %% [markdown]
# # Part 3 — Physical Time and a Time-Domain Plot
#
# For `N` samples at sampling rate `fs`:
#
# - Last sample timestamp: `(N - 1) / fs`
# - Nominal acquisition duration: `N / fs`
#
# These values differ by one sampling interval.

# %%
# Map machine-readable column names to figure labels and physical units.
channel_display_names = {
    "force_x_N": "Force X", "force_y_N": "Force Y", "force_z_N": "Force Z",
    "vibration_x_g": "Vibration X", "vibration_y_g": "Vibration Y",
    "vibration_z_g": "Vibration Z", "ae_rms_V": "AE-RMS",
}
channel_units = {
    "force_x_N": "N", "force_y_N": "N", "force_z_N": "N",
    "vibration_x_g": "g", "vibration_y_g": "g",
    "vibration_z_g": "g", "ae_rms_V": "V",
}

# %%
# [REQUIRED CHECKPOINT 3] Time Vector and Visualization
fs_hz = 50_000

# TODO: Construct physical time using np.arange(), len(data), and fs_hz.
time_s = ...

# TODO: Calculate the last sample timestamp and nominal acquisition duration.
last_sample_time_s = ...
nominal_acquisition_duration_s = ...

# TODO: Select one channel from channel_display_names.
selected_channel = ...
assert len(time_s) == len(data)
assert selected_channel in data.columns

selected_signal = data[selected_channel].to_numpy()

# TODO: Calculate the mean and sample standard deviation using ddof=1.
sample_mean = ...
sample_standard_deviation = ...

# TODO: Plot the selected signal against time with labels and physical units.
fig, ax = plt.subplots(figsize=(11, 4))
...
fig.tight_layout()
plt.show()

print(f"Last sample timestamp: {last_sample_time_s:.5f} s")
print(f"Nominal acquisition duration: {nominal_acquisition_duration_s:.5f} s")
print(f"Sample mean: {sample_mean:.6f} {channel_units[selected_channel]}")
print(f"Sample standard deviation: {sample_standard_deviation:.6f} {channel_units[selected_channel]}")

# %% [markdown]
# # Part 4 — Engineering Interpretation
#
# ## [REQUIRED CHECKPOINT 4] Observation, Possible Interpretation, and Limitation
#
# **Observation:** TODO: State one pattern or numerical fact directly supported
# by the plot or computed results.
#
# **Possible interpretation:** TODO: Provide one cautious engineering explanation.
#
# **Limitation:** TODO: Explain why this one record cannot confirm that explanation
# or establish wear, chatter, anomaly, or failure.
#
# **Reproducibility:** TODO: Restart the session, select **Run all**, and confirm
# that the completed notebook runs without errors.

# %% [markdown]
# # Submission Confirmation
#
# Rendered notebook checkboxes are not clickable. To record completion, edit
# this Markdown cell and change `[ ]` to `[x]`.
#
# - [ ] I entered my name and WSU AccessID.
# - [ ] I completed all required checkpoints.
# - [ ] I restarted the session and selected Run all.
# - [ ] I reviewed the notebook for execution errors.
# - [ ] I verified figure labels and physical units.
# - [ ] My completed code includes concise comments about processing steps,
#       assumptions, or physical units.
# - [ ] I downloaded both the `.ipynb` and PDF files.
# - [ ] I used `Lab02_Firstname_Lastname.ipynb` and
#       `Lab02_Firstname_Lastname.pdf`.
#
# ## References
#
# - [PHM Society: 2010 PHM Society Conference Data Challenge](https://phmsociety.org/phm_competition/2010-phm-society-conference-data-challenge/)
# - [Kaggle: PHM data challenge 2010, Version 1, CC0](https://www.kaggle.com/datasets/rabahba/phm-data-challenge-2010)
# - [NumPy documentation](https://numpy.org/doc/stable/)
# - [pandas documentation](https://pandas.pydata.org/docs/)
# - [Matplotlib documentation](https://matplotlib.org/stable/)
